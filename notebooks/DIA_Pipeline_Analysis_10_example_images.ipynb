# %%
import matplotlib.pyplot as plt
import lsst.afw.image as afwImage
from astropy.visualization import ZScaleInterval
import data_process_utils as dpu
interval = ZScaleInterval()
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.7.0/lib/python3.8/site-packages/GCRCatalogs/register.py:159: UserWarning: Site determined from env variable DESC_GCR_SITE = nersc, which differs from node name login22.chn
#   warnings.warn("Site determined from env variable {} = {}, which differs from node name {}".format(

# %%
data_dir = '/pscratch/sd/s/shl159/Cori/projects/fake_injection_v23/dia_improvement/devel/data'

# %%
coadd = afwImage.ExposureF(f'{data_dir}/patch_0to6/diff/dipole_examples/coadd/coadd_4639_00.fits')
calexp = afwImage.ExposureF(f'{data_dir}/patch_0to6/injection/00_20_21_1013665_79_i/fake_20/calexp/01013665-i/R20/calexp_01013665-i-R20-S21-det079.fits')
al_diff = afwImage.ExposureF(f'{data_dir}/patch_0to6/diff/dipole_examples/al/deepDiff/v01013665-fi/R20/diffexp_01013665-i-R20-S21-det079.fits')

# %%
info = calexp.getInfo()

# %%
info.

# %%
info.getSummaryStats()

# %%
info.getVisitInfo()
# Out:
# VisitInfo(exposureId=1013665079, exposureTime=30, darkTime=30, date=2026-02-05T02:49:34.310199836, UT1=nan, ERA=3.09233 rad, boresightRaDec=(58.6646572124, -30.7239450314), boresightAzAlt=(256.8201387375, +49.1362490579), boresightAirmass=1.32228, boresightRotAngle=2.99772 rad, rotType=1, observatory=-70.7494W, -30.2446N  2663, weather=Weather(nan, nan, 40), instrumentLabel='', id=0)

# %%
coadd_warped = dpu.warp_to_exposure(coadd, calexp)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.imshow(interval(coadd_warped.getImage().array), cmap='gray', origin='lower')
ax.set_axis_off()
plt.savefig('./plots_and_tables/coadd.jpg', dpi=100)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.imshow(interval(calexp.getImage().array), cmap='gray', origin='lower')
ax.set_axis_off()
plt.savefig('./plots_and_tables/calexp.jpg', dpi=100)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.imshow(interval(calexp.getImage().array), cmap='gray', origin='lower')
ax.set_axis_off()
plt.savefig('./plots_and_tables/calexp.jpg', dpi=100)
